# %%
import logging
import sys
from kiteconnect import KiteTicker
from kiteconnect import KiteConnect
from dotenv import load_dotenv
from get_token import get_token
from utils import read_env
from get_access_token import get_access_token
# Load the environment variables
load_dotenv()
## LOADING ENV VARS FROM .env
try:
    API_KEY = read_env("API_KEY")
    API_SECRET = read_env("API_SECRET")
    LOGIN = read_env("USERNAME")
    PASSW = read_env("PASSWORD")
    PIN = read_env("PIN")
    STREAMER_PATH = read_env("CHROMEDRIVER")
except LookupError as err:
    raise LookupError("Did not find the following env variable") from err

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
REQUEST_TOKEN = get_token((LOGIN, PASSW, PIN), API_KEY, STREAMER_PATH)
ACCESS_TOKEN = get_access_token((API_KEY, API_SECRET), REQUEST_TOKEN)
# Check if we've already got an access token.
if not ACCESS_TOKEN:
    print("Access token not found.")
    sys.exit(1)
else:
    try:
        # Initialise Kite Connect object with access token.
        kws = KiteTicker(API_KEY, ACCESS_TOKEN)
        print("Init Kite Done!!!!!!")
    except ValueError:
        raise ValueError("Invalid API key or Access token") from None
# Out:
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session {"capabilities": {"firstMatch": [{}], "alwaysMatch": {"browserName": "chrome", "pageLoadStrategy": "normal", "goog:chromeOptions": {"extensions": [], "args": ["--disable-extensions", "--disable-dev-shm-usage", "--no-sandbox", "--disable-gpu", "--headless"]}}}, "desiredCapabilities": {"browserName": "chrome", "pageLoadStrategy": "normal", "goog:chromeOptions": {"extensions": [], "args": ["--disable-extensions", "--disable-dev-shm-usage", "--no-sandbox", "--disable-gpu", "--headless"]}}}
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): localhost:55711
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session HTTP/1.1" 200 798
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/url {"url": "https://kite.zerodha.com/connect/login?v=3&api_key=3220bdydwgk0dgpo"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/url HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element {"using": "xpath", "value": "//*[@id=\"userid\"]"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element HTTP/1.1" 200 88
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element/f0c8341d-8473-40d2-8173-9df5129a4b93/value {"text": "UY3488", "value": ["U", "Y", "3", "4", "8", "8"], "id": "f0c8341d-8473-40d2-8173-9df5129a4b93"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element/f0c8341d-8473-40d2-8173-9df5129a4b93/value HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element {"using": "xpath", "value": "//*[@id=\"password\"]"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element HTTP/1.1" 200 88
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element/5ea31730-a138-4a6f-87b8-2cf5885dc4a9/value {"text": "JayIsASimp@123", "value": ["J", "a", "y", "I", "s", "A", "S", "i", "m", "p", "@", "1", "2", "3"], "id": "5ea31730-a138-4a6f-87b8-2cf5885dc4a9"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element/5ea31730-a138-4a6f-87b8-2cf5885dc4a9/value HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element {"using": "xpath", "value": "//*[@id=\"container\"]/div/div/div/form/div[4]/button"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element HTTP/1.1" 200 88
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element/6c730961-2e7e-4f0f-98ac-747d99dad8bd/click {"id": "6c730961-2e7e-4f0f-98ac-747d99dad8bd"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element/6c730961-2e7e-4f0f-98ac-747d99dad8bd/click HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element {"using": "xpath", "value": "//*[@id=\"pin\"]"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element HTTP/1.1" 200 88
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element/ddc4e8ab-26a6-4e54-b64d-2fcbc86db1b7/value {"text": "210575", "value": ["2", "1", "0", "5", "7", "5"], "id": "ddc4e8ab-26a6-4e54-b64d-2fcbc86db1b7"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element/ddc4e8ab-26a6-4e54-b64d-2fcbc86db1b7/value HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element {"using": "xpath", "value": "//*[@id=\"container\"]/div/div/div[2]/form/div[3]/button"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element HTTP/1.1" 200 88
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:POST http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/element/6c730961-2e7e-4f0f-98ac-747d99dad8bd/click {"id": "6c730961-2e7e-4f0f-98ac-747d99dad8bd"}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "POST /session/552ea49b8f25fc989f5c1ee3390233ee/element/6c730961-2e7e-4f0f-98ac-747d99dad8bd/click HTTP/1.1" 200 14
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:selenium.webdriver.remote.remote_connection:GET http://localhost:55711/session/552ea49b8f25fc989f5c1ee3390233ee/url {}
# DEBUG:urllib3.connectionpool:http://localhost:55711 "GET /session/552ea49b8f25fc989f5c1ee3390233ee/url HTTP/1.1" 200 121
# DEBUG:selenium.webdriver.remote.remote_connection:Finished Request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /session/token HTTP/1.1" 200 None
# Init Kite Done!!!!!!

# %%
kite = KiteConnect(API_KEY)

# %%
kite.set_access_token(ACCESS_TOKEN)

# %%
instruments = kite.instruments()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.kite.trade:443
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments HTTP/1.1" 200 1355315

# %%
# Out:
# [{'instrument_token': 275855110,
#   'exchange_token': '1077559',
#   'tradingsymbol': 'EURINR22APRFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 278434566,
#   'exchange_token': '1087635',
#   'tradingsymbol': 'EURINR22AUGFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 256503558,
#   'exchange_token': '1001967',
#   'tradingsymbol': 'EURINR22DECFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 274297350,
#   'exchange_token': '1071474',
#   'tradingsymbol': 'EURINR22FEBFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277817350,
#   'exchange_token': '1085224',
#   'tradingsymbol': 'EURINR22JULFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277171462,
#   'exchange_token': '1082701',
#   'tradingsymbol': 'EURINR22JUNFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275054086,
#   'exchange_token': '1074430',
#   'tradingsymbol': 'EURINR22MARFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 276514822,
#   'exchange_token': '1080136',
#   'tradingsymbol': 'EURINR22MAYFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 280510214,
#   'exchange_token': '1095743',
#   'tradingsymbol': 'EURINR22NOVFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279745542,
#   'exchange_token': '1092756',
#   'tradingsymbol': 'EURINR22OCTFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279052806,
#   'exchange_token': '1090050',
#   'tradingsymbol': 'EURINR22SEPFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 257142278,
#   'exchange_token': '1004462',
#   'tradingsymbol': 'EURINR23JANFUT',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2023, 1, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275854854,
#   'exchange_token': '1077558',
#   'tradingsymbol': 'GBPINR22APRFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 278434310,
#   'exchange_token': '1087634',
#   'tradingsymbol': 'GBPINR22AUGFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 256503302,
#   'exchange_token': '1001966',
#   'tradingsymbol': 'GBPINR22DECFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 274297094,
#   'exchange_token': '1071473',
#   'tradingsymbol': 'GBPINR22FEBFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277817094,
#   'exchange_token': '1085223',
#   'tradingsymbol': 'GBPINR22JULFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277171206,
#   'exchange_token': '1082700',
#   'tradingsymbol': 'GBPINR22JUNFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275053830,
#   'exchange_token': '1074429',
#   'tradingsymbol': 'GBPINR22MARFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 276514566,
#   'exchange_token': '1080135',
#   'tradingsymbol': 'GBPINR22MAYFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 280509958,
#   'exchange_token': '1095742',
#   'tradingsymbol': 'GBPINR22NOVFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279745286,
#   'exchange_token': '1092755',
#   'tradingsymbol': 'GBPINR22OCTFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279052550,
#   'exchange_token': '1090049',
#   'tradingsymbol': 'GBPINR22SEPFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 257142022,
#   'exchange_token': '1004461',
#   'tradingsymbol': 'GBPINR23JANFUT',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2023, 1, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275855366,
#   'exchange_token': '1077560',
#   'tradingsymbol': 'JPYINR22APRFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 278434822,
#   'exchange_token': '1087636',
#   'tradingsymbol': 'JPYINR22AUGFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 256503814,
#   'exchange_token': '1001968',
#   'tradingsymbol': 'JPYINR22DECFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 274297606,
#   'exchange_token': '1071475',
#   'tradingsymbol': 'JPYINR22FEBFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277817606,
#   'exchange_token': '1085225',
#   'tradingsymbol': 'JPYINR22JULFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277171718,
#   'exchange_token': '1082702',
#   'tradingsymbol': 'JPYINR22JUNFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275054342,
#   'exchange_token': '1074431',
#   'tradingsymbol': 'JPYINR22MARFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 276515078,
#   'exchange_token': '1080137',
#   'tradingsymbol': 'JPYINR22MAYFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 280510470,
#   'exchange_token': '1095744',
#   'tradingsymbol': 'JPYINR22NOVFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279745798,
#   'exchange_token': '1092757',
#   'tradingsymbol': 'JPYINR22OCTFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279053062,
#   'exchange_token': '1090051',
#   'tradingsymbol': 'JPYINR22SEPFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 257142534,
#   'exchange_token': '1004463',
#   'tradingsymbol': 'JPYINR23JANFUT',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2023, 1, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275854598,
#   'exchange_token': '1077557',
#   'tradingsymbol': 'USDINR22APRFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 278433798,
#   'exchange_token': '1087632',
#   'tradingsymbol': 'USDINR22AUGFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 256503046,
#   'exchange_token': '1001965',
#   'tradingsymbol': 'USDINR22DECFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 274296838,
#   'exchange_token': '1071472',
#   'tradingsymbol': 'USDINR22FEBFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277816838,
#   'exchange_token': '1085222',
#   'tradingsymbol': 'USDINR22JULFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 277170950,
#   'exchange_token': '1082699',
#   'tradingsymbol': 'USDINR22JUNFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 275053318,
#   'exchange_token': '1074427',
#   'tradingsymbol': 'USDINR22MARFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 276514310,
#   'exchange_token': '1080134',
#   'tradingsymbol': 'USDINR22MAYFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 280509702,
#   'exchange_token': '1095741',
#   'tradingsymbol': 'USDINR22NOVFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279745030,
#   'exchange_token': '1092754',
#   'tradingsymbol': 'USDINR22OCTFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 279052294,
#   'exchange_token': '1090048',
#   'tradingsymbol': 'USDINR22SEPFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 257141766,
#   'exchange_token': '1004460',
#   'tradingsymbol': 'USDINR23JANFUT',
#   'name': 'USDINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2023, 1, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'FUT',
#   'segment': 'BCD-FUT',
#   'exchange': 'BCD'},
#  {'instrument_token': 278580742,
#   'exchange_token': '1088206',
#   'tradingsymbol': 'EURAPR22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256575494,
#   'exchange_token': '1002248',
#   'tradingsymbol': 'EURAPR22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257168134,
#   'exchange_token': '1004563',
#   'tradingsymbol': 'EURAPR22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277876486,
#   'exchange_token': '1085455',
#   'tradingsymbol': 'EURAPR22JUL22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277236486,
#   'exchange_token': '1082955',
#   'tradingsymbol': 'EURAPR22JUN22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 276540934,
#   'exchange_token': '1080238',
#   'tradingsymbol': 'EURAPR22MAY22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280607238,
#   'exchange_token': '1096122',
#   'tradingsymbol': 'EURAPR22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279791622,
#   'exchange_token': '1092936',
#   'tradingsymbol': 'EURAPR22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279134214,
#   'exchange_token': '1090368',
#   'tradingsymbol': 'EURAPR22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256557318,
#   'exchange_token': '1002177',
#   'tradingsymbol': 'EURAUG22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257190406,
#   'exchange_token': '1004650',
#   'tradingsymbol': 'EURAUG22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280652294,
#   'exchange_token': '1096298',
#   'tradingsymbol': 'EURAUG22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279812614,
#   'exchange_token': '1093018',
#   'tradingsymbol': 'EURAUG22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279117318,
#   'exchange_token': '1090302',
#   'tradingsymbol': 'EURAUG22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257179910,
#   'exchange_token': '1004609',
#   'tradingsymbol': 'EURDEC22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275907334,
#   'exchange_token': '1077763',
#   'tradingsymbol': 'EURFEB22APR22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278532102,
#   'exchange_token': '1088016',
#   'tradingsymbol': 'EURFEB22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256553734,
#   'exchange_token': '1002163',
#   'tradingsymbol': 'EURFEB22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257187078,
#   'exchange_token': '1004637',
#   'tradingsymbol': 'EURFEB22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277857286,
#   'exchange_token': '1085380',
#   'tradingsymbol': 'EURFEB22JUL22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277256454,
#   'exchange_token': '1083033',
#   'tradingsymbol': 'EURFEB22JUN22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275190790,
#   'exchange_token': '1074964',
#   'tradingsymbol': 'EURFEB22MAR22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 276561926,
#   'exchange_token': '1080320',
#   'tradingsymbol': 'EURFEB22MAY22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280646406,
#   'exchange_token': '1096275',
#   'tradingsymbol': 'EURFEB22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279809542,
#   'exchange_token': '1093006',
#   'tradingsymbol': 'EURFEB22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279115014,
#   'exchange_token': '1090293',
#   'tradingsymbol': 'EURFEB22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278516486,
#   'exchange_token': '1087955',
#   'tradingsymbol': 'EURJUL22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256547078,
#   'exchange_token': '1002137',
#   'tradingsymbol': 'EURJUL22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257178886,
#   'exchange_token': '1004605',
#   'tradingsymbol': 'EURJUL22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280630790,
#   'exchange_token': '1096214',
#   'tradingsymbol': 'EURJUL22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279802886,
#   'exchange_token': '1092980',
#   'tradingsymbol': 'EURJUL22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279107078,
#   'exchange_token': '1090262',
#   'tradingsymbol': 'EURJUL22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278560006,
#   'exchange_token': '1088125',
#   'tradingsymbol': 'EURJUN22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256567814,
#   'exchange_token': '1002218',
#   'tradingsymbol': 'EURJUN22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257159686,
#   'exchange_token': '1004530',
#   'tradingsymbol': 'EURJUN22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277868550,
#   'exchange_token': '1085424',
#   'tradingsymbol': 'EURJUN22JUL22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280588550,
#   'exchange_token': '1096049',
#   'tradingsymbol': 'EURJUN22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279784966,
#   'exchange_token': '1092910',
#   'tradingsymbol': 'EURJUN22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279126022,
#   'exchange_token': '1090336',
#   'tradingsymbol': 'EURJUN22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275900934,
#   'exchange_token': '1077738',
#   'tradingsymbol': 'EURMAR22APR22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278518534,
#   'exchange_token': '1087963',
#   'tradingsymbol': 'EURMAR22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256548102,
#   'exchange_token': '1002141',
#   'tradingsymbol': 'EURMAR22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257180422,
#   'exchange_token': '1004611',
#   'tradingsymbol': 'EURMAR22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277888262,
#   'exchange_token': '1085501',
#   'tradingsymbol': 'EURMAR22JUL22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277248774,
#   'exchange_token': '1083003',
#   'tradingsymbol': 'EURMAR22JUN22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 276555526,
#   'exchange_token': '1080295',
#   'tradingsymbol': 'EURMAR22MAY22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280634118,
#   'exchange_token': '1096227',
#   'tradingsymbol': 'EURMAR22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279804422,
#   'exchange_token': '1092986',
#   'tradingsymbol': 'EURMAR22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279108102,
#   'exchange_token': '1090266',
#   'tradingsymbol': 'EURMAR22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278558726,
#   'exchange_token': '1088120',
#   'tradingsymbol': 'EURMAY22AUG22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256567046,
#   'exchange_token': '1002215',
#   'tradingsymbol': 'EURMAY22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257159174,
#   'exchange_token': '1004528',
#   'tradingsymbol': 'EURMAY22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277867782,
#   'exchange_token': '1085421',
#   'tradingsymbol': 'EURMAY22JUL22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277265926,
#   'exchange_token': '1083070',
#   'tradingsymbol': 'EURMAY22JUN22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280586758,
#   'exchange_token': '1096042',
#   'tradingsymbol': 'EURMAY22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279783686,
#   'exchange_token': '1092905',
#   'tradingsymbol': 'EURMAY22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279124742,
#   'exchange_token': '1090331',
#   'tradingsymbol': 'EURMAY22SEP22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 5, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256548870,
#   'exchange_token': '1002144',
#   'tradingsymbol': 'EURNOV22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257181702,
#   'exchange_token': '1004616',
#   'tradingsymbol': 'EURNOV22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 11, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256544006,
#   'exchange_token': '1002125',
#   'tradingsymbol': 'EUROCT22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257175814,
#   'exchange_token': '1004593',
#   'tradingsymbol': 'EUROCT22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280625158,
#   'exchange_token': '1096192',
#   'tradingsymbol': 'EUROCT22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 10, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256564230,
#   'exchange_token': '1002204',
#   'tradingsymbol': 'EURSEP22DEC22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257156102,
#   'exchange_token': '1004516',
#   'tradingsymbol': 'EURSEP22JAN23',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280579590,
#   'exchange_token': '1096014',
#   'tradingsymbol': 'EURSEP22NOV22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279780102,
#   'exchange_token': '1092891',
#   'tradingsymbol': 'EURSEP22OCT22',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278545158,
#   'exchange_token': '1088067',
#   'tradingsymbol': 'GBPAPR22AUG22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256561670,
#   'exchange_token': '1002194',
#   'tradingsymbol': 'GBPAPR22DEC22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257153286,
#   'exchange_token': '1004505',
#   'tradingsymbol': 'GBPAPR22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277863174,
#   'exchange_token': '1085403',
#   'tradingsymbol': 'GBPAPR22JUL22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277261830,
#   'exchange_token': '1083054',
#   'tradingsymbol': 'GBPAPR22JUN22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 276525062,
#   'exchange_token': '1080176',
#   'tradingsymbol': 'GBPAPR22MAY22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280662790,
#   'exchange_token': '1096339',
#   'tradingsymbol': 'GBPAPR22NOV22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279777286,
#   'exchange_token': '1092880',
#   'tradingsymbol': 'GBPAPR22OCT22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279120390,
#   'exchange_token': '1090314',
#   'tradingsymbol': 'GBPAPR22SEP22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 4, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256541446,
#   'exchange_token': '1002115',
#   'tradingsymbol': 'GBPAUG22DEC22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257174022,
#   'exchange_token': '1004586',
#   'tradingsymbol': 'GBPAUG22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280620806,
#   'exchange_token': '1096175',
#   'tradingsymbol': 'GBPAUG22NOV22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279797510,
#   'exchange_token': '1092959',
#   'tradingsymbol': 'GBPAUG22OCT22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279101446,
#   'exchange_token': '1090240',
#   'tradingsymbol': 'GBPAUG22SEP22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 8, 26),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257166086,
#   'exchange_token': '1004555',
#   'tradingsymbol': 'GBPDEC22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 12, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275892230,
#   'exchange_token': '1077704',
#   'tradingsymbol': 'GBPFEB22APR22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278496518,
#   'exchange_token': '1087877',
#   'tradingsymbol': 'GBPFEB22AUG22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256538118,
#   'exchange_token': '1002102',
#   'tradingsymbol': 'GBPFEB22DEC22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257171206,
#   'exchange_token': '1004575',
#   'tradingsymbol': 'GBPFEB22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277880070,
#   'exchange_token': '1085469',
#   'tradingsymbol': 'GBPFEB22JUL22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277238790,
#   'exchange_token': '1082964',
#   'tradingsymbol': 'GBPFEB22JUN22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275156742,
#   'exchange_token': '1074831',
#   'tradingsymbol': 'GBPFEB22MAR22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 276545030,
#   'exchange_token': '1080254',
#   'tradingsymbol': 'GBPFEB22MAY22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280610822,
#   'exchange_token': '1096136',
#   'tradingsymbol': 'GBPFEB22NOV22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279794438,
#   'exchange_token': '1092947',
#   'tradingsymbol': 'GBPFEB22OCT22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279098886,
#   'exchange_token': '1090230',
#   'tradingsymbol': 'GBPFEB22SEP22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278570758,
#   'exchange_token': '1088167',
#   'tradingsymbol': 'GBPJUL22AUG22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256572422,
#   'exchange_token': '1002236',
#   'tradingsymbol': 'GBPJUL22DEC22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257164806,
#   'exchange_token': '1004550',
#   'tradingsymbol': 'GBPJUL22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280596742,
#   'exchange_token': '1096081',
#   'tradingsymbol': 'GBPJUL22NOV22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279788550,
#   'exchange_token': '1092924',
#   'tradingsymbol': 'GBPJUL22OCT22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279130118,
#   'exchange_token': '1090352',
#   'tradingsymbol': 'GBPJUL22SEP22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 7, 27),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278526726,
#   'exchange_token': '1087995',
#   'tradingsymbol': 'GBPJUN22AUG22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256551942,
#   'exchange_token': '1002156',
#   'tradingsymbol': 'GBPJUN22DEC22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 257184262,
#   'exchange_token': '1004626',
#   'tradingsymbol': 'GBPJUN22JAN23',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 277854982,
#   'exchange_token': '1085371',
#   'tradingsymbol': 'GBPJUN22JUL22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 280642310,
#   'exchange_token': '1096259',
#   'tradingsymbol': 'GBPJUN22NOV22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279808006,
#   'exchange_token': '1093000',
#   'tradingsymbol': 'GBPJUN22OCT22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 279112966,
#   'exchange_token': '1090285',
#   'tradingsymbol': 'GBPJUN22SEP22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 6, 28),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 275925254,
#   'exchange_token': '1077833',
#   'tradingsymbol': 'GBPMAR22APR22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 278572038,
#   'exchange_token': '1088172',
#   'tradingsymbol': 'GBPMAR22AUG22',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 3, 29),
#   'strike': 0.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'EQ',
#   'segment': 'BCD',
#   'exchange': 'BCD'},
#  {'instrument_token': 256573190,
#   'exchange_token': '1002239',
#   'tradingsymbol': 'GBPMAR22DEC22',
# ...
#   'tradingsymbol': 'EURINR22SEP88.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 539616774,
#   'exchange_token': '2107878',
#   'tradingsymbol': 'EURINR22SEP88.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 539593990,
#   'exchange_token': '2107789',
#   'tradingsymbol': 'EURINR22SEP89.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 539590150,
#   'exchange_token': '2107774',
#   'tradingsymbol': 'EURINR22SEP89.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 539534342,
#   'exchange_token': '2107556',
#   'tradingsymbol': 'EURINR22SEP89.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 539530246,
#   'exchange_token': '2107540',
#   'tradingsymbol': 'EURINR22SEP89.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 9, 28),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541321990,
#   'exchange_token': '2114539',
#   'tradingsymbol': 'GBPINR22FEB100.0000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541317382,
#   'exchange_token': '2114521',
#   'tradingsymbol': 'GBPINR22FEB100.0000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541474566,
#   'exchange_token': '2115135',
#   'tradingsymbol': 'GBPINR22FEB100.2500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541469958,
#   'exchange_token': '2115117',
#   'tradingsymbol': 'GBPINR22FEB100.2500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541335814,
#   'exchange_token': '2114593',
#   'tradingsymbol': 'GBPINR22FEB100.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541331462,
#   'exchange_token': '2114576',
#   'tradingsymbol': 'GBPINR22FEB100.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541466374,
#   'exchange_token': '2115103',
#   'tradingsymbol': 'GBPINR22FEB100.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541463046,
#   'exchange_token': '2115090',
#   'tradingsymbol': 'GBPINR22FEB100.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 100.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541456134,
#   'exchange_token': '2115063',
#   'tradingsymbol': 'GBPINR22FEB101.0000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541452038,
#   'exchange_token': '2115047',
#   'tradingsymbol': 'GBPINR22FEB101.0000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541357830,
#   'exchange_token': '2114679',
#   'tradingsymbol': 'GBPINR22FEB101.2500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541353990,
#   'exchange_token': '2114664',
#   'tradingsymbol': 'GBPINR22FEB101.2500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541446406,
#   'exchange_token': '2115025',
#   'tradingsymbol': 'GBPINR22FEB101.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541443590,
#   'exchange_token': '2115014',
#   'tradingsymbol': 'GBPINR22FEB101.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541349382,
#   'exchange_token': '2114646',
#   'tradingsymbol': 'GBPINR22FEB101.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541346310,
#   'exchange_token': '2114634',
#   'tradingsymbol': 'GBPINR22FEB101.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 101.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541336838,
#   'exchange_token': '2114597',
#   'tradingsymbol': 'GBPINR22FEB102.0000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541332230,
#   'exchange_token': '2114579',
#   'tradingsymbol': 'GBPINR22FEB102.0000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541466630,
#   'exchange_token': '2115104',
#   'tradingsymbol': 'GBPINR22FEB102.2500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541463814,
#   'exchange_token': '2115093',
#   'tradingsymbol': 'GBPINR22FEB102.2500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541327110,
#   'exchange_token': '2114559',
#   'tradingsymbol': 'GBPINR22FEB102.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541324550,
#   'exchange_token': '2114549',
#   'tradingsymbol': 'GBPINR22FEB102.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541457926,
#   'exchange_token': '2115070',
#   'tradingsymbol': 'GBPINR22FEB102.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541454854,
#   'exchange_token': '2115058',
#   'tradingsymbol': 'GBPINR22FEB102.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 102.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541446918,
#   'exchange_token': '2115027',
#   'tradingsymbol': 'GBPINR22FEB103.0000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541444358,
#   'exchange_token': '2115017',
#   'tradingsymbol': 'GBPINR22FEB103.0000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541349638,
#   'exchange_token': '2114647',
#   'tradingsymbol': 'GBPINR22FEB103.2500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541347078,
#   'exchange_token': '2114637',
#   'tradingsymbol': 'GBPINR22FEB103.2500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541439494,
#   'exchange_token': '2114998',
#   'tradingsymbol': 'GBPINR22FEB103.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541436166,
#   'exchange_token': '2114985',
#   'tradingsymbol': 'GBPINR22FEB103.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541364998,
#   'exchange_token': '2114707',
#   'tradingsymbol': 'GBPINR22FEB103.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541361414,
#   'exchange_token': '2114693',
#   'tradingsymbol': 'GBPINR22FEB103.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 103.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541496326,
#   'exchange_token': '2115220',
#   'tradingsymbol': 'GBPINR22FEB95.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 95.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541493254,
#   'exchange_token': '2115208',
#   'tradingsymbol': 'GBPINR22FEB95.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 95.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541433606,
#   'exchange_token': '2114975',
#   'tradingsymbol': 'GBPINR22FEB95.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 95.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541429254,
#   'exchange_token': '2114958',
#   'tradingsymbol': 'GBPINR22FEB95.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 95.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541392134,
#   'exchange_token': '2114813',
#   'tradingsymbol': 'GBPINR22FEB96.0000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541388038,
#   'exchange_token': '2114797',
#   'tradingsymbol': 'GBPINR22FEB96.0000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541323014,
#   'exchange_token': '2114543',
#   'tradingsymbol': 'GBPINR22FEB96.2500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541318406,
#   'exchange_token': '2114525',
#   'tradingsymbol': 'GBPINR22FEB96.2500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541381638,
#   'exchange_token': '2114772',
#   'tradingsymbol': 'GBPINR22FEB96.5000CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541379846,
#   'exchange_token': '2114765',
#   'tradingsymbol': 'GBPINR22FEB96.5000PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541312262,
#   'exchange_token': '2114501',
#   'tradingsymbol': 'GBPINR22FEB96.7500CE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 541308422,
#   'exchange_token': '2114486',
#   'tradingsymbol': 'GBPINR22FEB96.7500PE',
#   'name': 'GBPINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2022, 2, 24),
#   'strike': 96.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  ...]
